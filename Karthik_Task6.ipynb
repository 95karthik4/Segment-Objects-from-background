# %% [markdown]
# # Object Extraction Using Thresholding
# This notebook performs object extraction using several thresholding techniques.

# %%
import cv2
import matplotlib.pyplot as plt

# Load image
img = cv2.imread('task_6.jpg')

img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img_rgb)
plt.title("Input Image")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(3023.5), np.float64(4031.5), np.float64(-0.5))

# %%
# Convert to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

plt.imshow(gray, cmap='gray')
plt.title("Grayscale Image")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(3023.5), np.float64(4031.5), np.float64(-0.5))

# %%
# Global Thresholding
_, global_thresh = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)

plt.imshow(global_thresh, cmap='gray')
plt.title("Global Threshold")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(3023.5), np.float64(4031.5), np.float64(-0.5))

# %%
# Otsu's Thresholding
_, otsu_thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

plt.imshow(otsu_thresh, cmap='gray')
plt.title("Otsu Threshold")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(3023.5), np.float64(4031.5), np.float64(-0.5))

# %%
# Adaptive Mean Thresholding
adaptive_mean = cv2.adaptiveThreshold(gray,255,
                                      cv2.ADAPTIVE_THRESH_MEAN_C,
                                      cv2.THRESH_BINARY,11,2)

plt.imshow(adaptive_mean, cmap='gray')
plt.title("Adaptive Mean Threshold")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(3023.5), np.float64(4031.5), np.float64(-0.5))

# %%
# Adaptive Gaussian Thresholding
adaptive_gauss = cv2.adaptiveThreshold(gray,255,
                                       cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
                                       cv2.THRESH_BINARY,11,2)

plt.imshow(adaptive_gauss, cmap='gray')
plt.title("Adaptive Gaussian Threshold")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(3023.5), np.float64(4031.5), np.float64(-0.5))
